# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
kitty = plt.imread('../img/cute_kitty_gray.jpg')
kitty = np.array(kitty, dtype=float)
kitty += 0.1*np.random.normal(size=kitty.shape)
kitty /= kitty.max()

# %%
plt.imshow(kitty)

# %%
plt.hist(kitty.flat)
plt.xlabel('intensity')
plt.ylabel('counts')
plt.title('Histogram of all Datapoints')

# %%
def plot_timestep(t):
    plt.hist(kitty[t], alpha=0.7, ec='k', bins=np.arange(0,1.1, step=0.1), label='ts={}'.format(t))
    plt.xlabel('intensity')
    plt.ylabel('counts')

# %%
timesteps = np.array([0,10,150])
print ','.join(timesteps.astype(str))
for t in timesteps:
    plot_timestep(t)
plt.title('Histogram of intensities at timesteps {}'.format(', '.join(timesteps.astype(str))))
plt.legend()
# Out:
# 0,10,150

# %%
for t in timesteps:
    plt.plot(kitty[t], marker='o')
plt.xlabel('frequency')
plt.ylabel('intensity')
plt.xlim(500, 520)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7fee9ba95a8f> in <module>()
# ----> 1 for t in timesteps:
#       2     plt.plot(kitty[t], marker='o')
#       3 plt.xlabel('frequency')
#       4 plt.ylabel('intensity')
#       5 plt.xlim(500, 520)
#
# NameError: name 'timesteps' is not defined

# %%
xmin, xmax = 500, 510
X = np.arange(xmin, xmax)
for t in [0, 80, 150]:
    Y = kitty[t][xmin:xmax]
    plt.scatter(X, Y)
